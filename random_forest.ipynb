# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, r2_score

# %%
#reading the csv in drive
statistical_features=pd.read_csv('/content/drive/MyDrive/W1/statistical_features.csv')
concatenated_df_statistical=pd.read_csv('/content/drive/MyDrive/W1/concatenated_df_statistical.csv')

# %%
#splitting all statistical features data for training and testing
from sklearn.model_selection import train_test_split
X = statistical_features
y = concatenated_df_statistical['Wear']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=102)

# %%
#passing all statistical features to random forest
from sklearn.ensemble import RandomForestRegressor
rf_regressor = RandomForestRegressor(n_estimators=100, n_jobs=3)
rf_regressor.fit(X_train, y_train)
y_pred = rf_regressor.predict(X_test)

# %%
#checking performance of random forest model on all statistical features

mse_rf = mean_squared_error(y_test, y_pred)
mape_rf = mean_absolute_percentage_error(y_test, y_pred)
r2_rf = r2_score(y_test, y_pred)

print("Mean squared error for RF model:", mse_rf)
print("Mean absolute percentage error for RF model:", mape_rf)
print("R2 score for RF model:", r2_rf)
# Out:
# Mean squared error for RF model: 1.1097662771284127e-08
# Mean absolute percentage error for RF model: 7.8228273052712e-05
# R2 score for RF model: 0.999991822076754

# %%
graph=pd.DataFrame({'Actual':y_test,'Predict':y_pred}).sort_values('Actual',ascending=True)
size=np.arange(0,graph.shape[0],1)

import matplotlib.pyplot as plt
plt.figure(figsize=(8,5), dpi=100)
plt.ylabel('tool wear')
plt.xlabel('data points')
plt.plot(size,graph.Actual, label='actual value')
plt.plot(size,graph.Predict.sort_values(), label='predicted values')
plt.plot(title='actual value')
plt.legend()

# %%
#reading the csv in drive
spectral_features=pd.read_csv('/content/drive/MyDrive/W1/spectral_features.csv')
concatenated_df_spectral=pd.read_csv('/content/drive/MyDrive/W1/concatenated_df_spectral.csv')

# %%
#splitting all spectral features data for training and testing
X = spectral_features
y = concatenated_df_spectral['Wear']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=102)

# %%
#passing all spectral features to random forest
rf_regressor = RandomForestRegressor(n_estimators=100, n_jobs=3)
rf_regressor.fit(X_train, y_train)
y_pred = rf_regressor.predict(X_test)

# %%
#checking performance of random forest model on all spectral features

mse_rf = mean_squared_error(y_test, y_pred)
mape_rf = mean_absolute_percentage_error(y_test, y_pred)
r2_rf = r2_score(y_test, y_pred)

print("Mean squared error for RF model:", mse_rf)
print("Mean absolute percentage error for RF model:", mape_rf)
print("R2 score for RF model:", r2_rf)
# Out:
# Mean squared error for RF model: 2.3722871452420426e-08
# Mean absolute percentage error for RF model: 0.0001034302381834987
# R2 score for RF model: 0.9999825184972807

# %%
graph=pd.DataFrame({'Actual':y_test,'Predict':y_pred}).sort_values('Actual',ascending=True)
size=np.arange(0,graph.shape[0],1)

import matplotlib.pyplot as plt
plt.figure(figsize=(8,5), dpi=100)
plt.ylabel('tool wear')
plt.xlabel('data points')
plt.plot(size,graph.Actual, label='actual value')
plt.plot(size,graph.Predict.sort_values(), label='predicted values')
plt.plot(title='actual value')
plt.legend()

# %%
#reading the csv in drive
temporal_features=pd.read_csv('/content/drive/MyDrive/W1/temporal_features.csv')
concatenated_df_temporal=pd.read_csv('/content/drive/MyDrive/W1/concatenated_df_temporal.csv')

# %%
#splitting all temporal features data for training and testing
X = temporal_features
y = concatenated_df_temporal['Wear']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=102)

# %%
#passing all temporal features to random forest
rf_regressor = RandomForestRegressor(n_estimators=100, n_jobs=3)
rf_regressor.fit(X_train, y_train)
y_pred = rf_regressor.predict(X_test)

# %%
#checking performance of random forest model on all temporal features

mse_rf = mean_squared_error(y_test, y_pred)
mape_rf = mean_absolute_percentage_error(y_test, y_pred)
r2_rf = r2_score(y_test, y_pred)

print("Mean squared error for RF model:", mse_rf)
print("Mean absolute percentage error for RF model:", mape_rf)
print("R2 score for RF model:", r2_rf)
# Out:
# Mean squared error for RF model: 0.00038570458889816375
# Mean absolute percentage error for RF model: 0.08971932271417282
# R2 score for RF model: 0.7157723577777815

# %%
graph=pd.DataFrame({'Actual':y_test,'Predict':y_pred}).sort_values('Actual',ascending=True)
size=np.arange(0,graph.shape[0],1)

import matplotlib.pyplot as plt
plt.figure(figsize=(8,5), dpi=100)
plt.ylabel('tool wear')
plt.xlabel('data points')
plt.plot(size,graph.Actual, label='actual value')
plt.plot(size,graph.Predict.sort_values(), label='predicted values')
plt.plot(title='actual value')
plt.legend()
